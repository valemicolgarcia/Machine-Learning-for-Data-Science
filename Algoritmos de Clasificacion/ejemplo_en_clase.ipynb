# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
url='https://raw.githubusercontent.com/Geerdata/DS/main/Datacoder/Arc.%20Modelo/WA_Fn-UseC_-Telco-Customer-Churn.csv'

df= pd.read_csv(url,sep=',')

df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
x = df[['InternetService', 'TotalCharges', 'Contract', 'PaymentMethod']].copy()
y = df[['Churn']].copy()

# %%
x.head()
# Out:
#   InternetService TotalCharges        Contract              PaymentMethod
# 0             DSL        29.85  Month-to-month           Electronic check
# 1             DSL       1889.5        One year               Mailed check
# 2             DSL       108.15  Month-to-month               Mailed check
# 3             DSL      1840.75        One year  Bank transfer (automatic)
# 4     Fiber optic       151.65  Month-to-month           Electronic check

# %%
x_encoded = pd.get_dummies(x)
x_encoded.head()
# Out:
#    InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 0                 True                        False               False
# 1                 True                        False               False
# 2                 True                        False               False
# 3                 True                        False               False
# 4                False                         True               False
#
#    TotalCharges_   TotalCharges_100.2  TotalCharges_100.25  \
# 0           False               False                False
# 1           False               False                False
# 2           False               False                False
# 3           False               False                False
# 4           False               False                False
#
#    TotalCharges_100.35  TotalCharges_100.4  TotalCharges_100.8  \
# 0                False               False               False
# ...

# %% [markdown]
# Ahora no va 0,1 sino que muestra true false

# %%
x_encoded.shape
# Out:
# (7043, 6541)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_encoded, y, test_size=0.3, random_state=42)#test depende del tamaño del dataset en general, semilla de donde arranca

# %%
# Entrenar el arbol
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

# %%
pred=clf.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true=y_test,y_pred=pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.81      0.89      0.85      1539
#          Yes       0.61      0.45      0.52       574
#
#     accuracy                           0.77      2113
#    macro avg       0.71      0.67      0.69      2113
# weighted avg       0.76      0.77      0.76      2113

# %% [markdown]
# De todo el muestreo se llega al 77% de acertividad, a nivel entrenamiento es bueno
# - Precision: El objetivo principal es predecir los que se van a dar de baja, nuestro modelo tiene mas precision en las personas que no se van a dar de baja, con respecto a las que si se van a dar de baja.
