# %% [markdown]
# # **Lectura de archivos planos (Headers)**

# %%
import pandas as pd

# %%
pd.read_csv('C:\Users\VICTUS\Documents\2024\MACHINE LEARNING FOR DATA SCIENCE\Datos\TXT\test.txt', sep =' ', header= None )

# %%
pd.read_csv('/test.txt', sep =' ', names=['z','u','t','y', 'mensaje'])

# %%
df = pd.read_csv('dates.txt', sep=',')
df.dtypes

# %%
df = pd.read_csv('dates.txt', sep=',', parse_dates=['date'])
df.dtypes

# %%
df

# %%
df = pd.read_csv('dates_4.txt', sep=',', parse_dates=[['year','month','day']])
df

# %%
df.info()

# %%
df = pd.read_csv('encuesta.txt', dtype=({"asistio": bool, "Tarea":bool} ))
df

# %%
df.info()

# %% [markdown]
# SQL

# %%
import sqlite3 as sql
conn= sql.connect('nba_salary.sqlite')
conn

# %%
# Visualizar las tablas
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor. fetchall())
# Out:
# [('NBA_season1718_salary',), ('Seasons_Stats',)]

# %%
df_salary = pd.read_sql_query("SELECT * from NBA_season1718_salary", conn)
df_salary.head()
# Out:
#     X1          Player   Tm  season17_18
# 0  1.0   Stephen Curry  GSW   34682550.0
# 1  2.0    LeBron James  CLE   33285709.0
# 2  3.0    Paul Millsap  DEN   31269231.0
# 3  4.0  Gordon Hayward  BOS   29727900.0
# 4  5.0   Blake Griffin  DET   29512900.0

# %%
df_stats = pd.read_sql_query("SELECT * from Seasons_Stats", conn)
df_stats.head()
# Out:
#     X1    Year           Player  Pos   Age   Tm     G  GS  MP  PER  ...  \
# 0  0.0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN  ...
# 1  1.0  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN  ...
# 2  2.0  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN  ...
# 3  3.0  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN  ...
# 4  4.0  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN  ...
#
#      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %%
pd.read_excel?

# %%
df = pd.read_excel('/content/defaultoutput.xlsx', sheet_name='Sheet1', usecols = "A,C,F")
df
# Out:
#       Unnamed: 0     ID Marital_Status
# 0              0   5524         Single
# 1              1   2174         Single
# 2              2   4141       Together
# 3              3   6182       Together
# 4              4   5324        Married
# ...          ...    ...            ...
# 2235        2235  10870        Married
# 2236        2236   4001       Together
# 2237        2237   7270       Divorced
# 2238        2238   8235       Together
# 2239        2239   9405        Married
#
# [2240 rows x 3 columns]

# %%
df = pd.read_excel('/content/defaultoutput.xlsx', sheet_name=0, usecols = "G:P")
df
# Out:
#        Income  Kidhome  Teenhome Dt_Customer  Recency  MntWines  MntFruits  \
# 0     58138.0        0         0  04-09-2012       58       635         88
# 1     46344.0        1         1  08-03-2014       38        11          1
# 2     71613.0        0         0  21-08-2013       26       426         49
# 3     26646.0        1         0  10-02-2014       26        11          4
# 4     58293.0        1         0  19-01-2014       94       173         43
# ...       ...      ...       ...         ...      ...       ...        ...
# 2235  61223.0        0         1  13-06-2013       46       709         43
# 2236  64014.0        2         1  10-06-2014       56       406          0
# 2237  56981.0        0         0  25-01-2014       91       908         48
# 2238  69245.0        0         1  24-01-2014        8       428         30
# 2239  52869.0        1         1  15-10-2012       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts
# 0                 546              172                88
# 1                   6                2                 1
# 2                 127              111                21
# 3                  20               10                 3
# 4                 118               46                27
# ...               ...              ...               ...
# 2235              182               42               118
# 2236               30                0                 0
# 2237              217               32                12
# 2238              214               80                30
# 2239               61                2                 1
#
# [2240 rows x 10 columns]

# %%
df = pd.read_excel('/content/defaultoutput.xlsx', sheet_name=0, usecols = "C:F,H,J:N")
df
# Out:
#          ID  Year_Birth   Education Marital_Status  Kidhome Dt_Customer  \
# 0      5524        1957  Graduation         Single        0  04-09-2012
# 1      2174        1954  Graduation         Single        1  08-03-2014
# 2      4141        1965  Graduation       Together        0  21-08-2013
# 3      6182        1984  Graduation       Together        1  10-02-2014
# 4      5324        1981         PhD        Married        1  19-01-2014
# ...     ...         ...         ...            ...      ...         ...
# 2235  10870        1967  Graduation        Married        0  13-06-2013
# 2236   4001        1946         PhD       Together        2  10-06-2014
# 2237   7270        1981  Graduation       Divorced        0  25-01-2014
# 2238   8235        1956      Master       Together        0  24-01-2014
# 2239   9405        1954         PhD        Married        1  15-10-2012
#
#       Recency  MntWines  MntFruits  MntMeatProducts
# 0          58       635         88              546
# 1          38        11          1                6
# 2          26       426         49              127
# 3          26        11          4               20
# 4          94       173         43              118
# ...       ...       ...        ...              ...
# 2235       46       709         43              182
# 2236       56       406          0               30
# 2237       91       908         48              217
# 2238        8       428         30              214
# 2239       40        84          3               61
#
# [2240 rows x 10 columns]

# %%
xls = pd.ExcelFile('/content/defaultoutput.xlsx')
xls.parse(sheet_name='Sheet1')
# Out:
#       Unnamed: 0  index     ID  Year_Birth   Education Marital_Status  \
# 0              0      0   5524        1957  Graduation         Single
# 1              1      1   2174        1954  Graduation         Single
# 2              2      2   4141        1965  Graduation       Together
# 3              3      3   6182        1984  Graduation       Together
# 4              4      4   5324        1981         PhD        Married
# ...          ...    ...    ...         ...         ...            ...
# 2235        2235   2235  10870        1967  Graduation        Married
# 2236        2236   2236   4001        1946         PhD       Together
# 2237        2237   2237   7270        1981  Graduation       Divorced
# 2238        2238   2238   8235        1956      Master       Together
# 2239        2239   2239   9405        1954         PhD        Married
#
#        Income  Kidhome  Teenhome Dt_Customer  ...  AcceptedCmp5  AcceptedCmp1  \
# 0     58138.0        0         0  04-09-2012  ...         False         False
# 1     46344.0        1         1  08-03-2014  ...         False         False
# 2     71613.0        0         0  21-08-2013  ...         False         False
# 3     26646.0        1         0  10-02-2014  ...         False         False
# 4     58293.0        1         0  19-01-2014  ...         False         False
# ...       ...      ...       ...         ...  ...           ...           ...
# 2235  61223.0        0         1  13-06-2013  ...         False         False
# 2236  64014.0        2         1  10-06-2014  ...         False          True
# 2237  56981.0        0         0  25-01-2014  ...         False         False
# 2238  69245.0        0         1  24-01-2014  ...         False         False
# 2239  52869.0        1         1  15-10-2012  ...         False         False
#
#       AcceptedCmp2  Complain  Z_CostContact  Z_Revenue  Response  \
# 0            False     False              3         11      True
# 1            False     False              3         11     False
# 2            False     False              3         11     False
# 3            False     False              3         11     False
# 4            False     False              3         11     False
# ...            ...       ...            ...        ...       ...
# 2235         False     False              3         11     False
# 2236         False     False              3         11     False
# 2237         False     False              3         11     False
# 2238         False     False              3         11     False
# 2239         False     False              3         11      True
#
#       MostExpensive  Marital_Status_key  Education_key
# 0             Wines                   0              1
# 1             Wines                   0              1
# 2             Wines                   2              1
# 3      MeatProducts                   2              1
# 4             Wines                   1              0
# ...             ...                 ...            ...
# 2235          Wines                   1              1
# 2236          Wines                   2              0
# 2237          Wines                   3              1
# 2238          Wines                   2              2
# 2239          Wines                   1              0
#
# [2240 rows x 34 columns]

# %% [markdown]
# #**SQL**

# %% [markdown]
# SQL Lite
# SQLite es probablemente la base de datos más sencilla para conectarse con una aplicación de Python, ya que no necesita instalar ningún módulo SQL de Python externo para hacerlo. De manera predeterminada, su instalación de Python contiene una biblioteca SQL de Python llamada sqlite3 que puede usar para interactuar con una base de datos SQLite.
#
# Además, las bases de datos SQLite no tienen servidor y son independientes, ya que leen y escriben datos en un archivo. Esto significa que, a diferencia de MySQL y PostgreSQL, ¡ni siquiera necesita instalar y ejecutar un servidor SQLite para realizar operaciones de base de datos!
#
# Miremos como conectarnos a sqlite3 con una base de datos en Python:

# %%
#pip install sqlite3
import sqlite3
import pandas as pd

# %%
# Ejemplo con Base David
path = '/content/david.sqlite'   #Direccion / Ruta

sql = sqlite3.connect(path)      #Connect para conexion a la BD

cursor = sql.cursor()            #Cursor es un objeto para manejar las consultas

# %%
#Explorar la BBDD
cursor.execute ("SELECT name from sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('users',), ('sqlite_sequence',), ('posts',), ('comments',), ('likes',)]

# %%
query = 'select * from posts'
cursor.execute(query)
print(cursor.fetchall())
# Out:
# [(1, 'Feliz', 'Me siento feliz hoy', 1), (2, 'Caliente', 'El clima esta caliente hoy', 2), (3, 'Ayuda', 'Necesito ayuda en esto', 2), (4, 'Buenas noticias', 'Me casare pronto', 1), (5, 'Juego interesante', 'Fue genial jugar al tenis', 5), (6, 'Fiesta', 'Alguno quiere venir a esta fiesta hoy?', 3), (7, 'Feliz', 'Me siento feliz hoy', 1), (8, 'Caliente', 'El clima esta caliente hoy', 2), (9, 'Ayuda', 'Necesito ayuda en esto', 2), (10, 'Buenas noticias', 'Me casare pronto', 1), (11, 'Juego interesante', 'Fue genial jugar al tenis', 5), (12, 'Fiesta', 'Alguno quiere venir a esta fiesta hoy?', 3)]

# %% [markdown]
# **Como Hacer Consulta con Pandas**

# %%
query1 = 'select * from users'
query2 = 'select * from posts'
query3 = 'select * from comments'
query4 = 'select * from likes'
query5 = 'select * from sqlite_sequence'

users = pd.read_sql_query(query1,sql)
posts = pd.read_sql_query(query2,sql)
comments = pd.read_sql_query(query3,sql)
likes = pd.read_sql_query(query4,sql)
sqlite = pd.read_sql_query(query5,sql)

# %%
comments
# Out:
#     id                       text  user_id  post_id
# 0    1             Cuenta conmigo        1        6
# 1    2         Que tipo de ayuda?        5        3
# 2    3             Felicitaciones        2        4
# 3    4  Estuve jugando con Rafael        4        5
# 4    5     Te ayudo con tu tesis?        2        3
# 5    6      Muchas felicitaciones        5        4
# 6    7             Cuenta conmigo        1        6
# 7    8         Que tipo de ayuda?        5        3
# 8    9             Felicitaciones        2        4
# 9   10  Estuve jugando con Rafael        4        5
# 10  11     Te ayudo con tu tesis?        2        3
# 11  12      Muchas felicitaciones        5        4

# %%
#Script completo de Query largas

sql = sqlite3.connect(path)
cursor = sql.cursor()

query = '''
select *
from users
'''

users = pd.read_sql_query(query,sql)
cursor.close()
sql.close()

# %% [markdown]
# **Libreria cx_Oracle**

# %%
#python -m pip install cx_Oracle --upgrade --user

#import cx_Oracle

# Connect as user "hr" with password "welcome" to the "orclpdb1" service running on this computer.
#connection = cx_Oracle.connect(user="hr", password="welcome",
                               #dsn="localhost/orclpdb1")

#cursor = connection.cursor()
#cursor.execute("""
#        SELECT first_name, last_name
#        FROM employees
#        WHERE department_id = :did AND employee_id > :eid""",
#        did = 50,
#        eid = 190)

#for fname, lname in cursor:
#    print("Values:", fname, lname)

# %%
#Instalacion alchemy
# !pip install --upgrade --no-deps git+https://github.com/psychemedia/eralchemy.git
# Out:
# Collecting git+https://github.com/psychemedia/eralchemy.git
#   Cloning https://github.com/psychemedia/eralchemy.git to /tmp/pip-req-build-itadlzqn
#   Running command git clone --filter=blob:none --quiet https://github.com/psychemedia/eralchemy.git /tmp/pip-req-build-itadlzqn
#   Resolved https://github.com/psychemedia/eralchemy.git to commit 7b90be5e46e997006eff9ff8a287c7fa8cf9687c
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ERAlchemy
#   Building wheel for ERAlchemy (setup.py) ... done
#   Created wheel for ERAlchemy: filename=ERAlchemy-1.2.9-py2.py3-none-any.whl size=16016 sha256=cc11d2a08480195a51fc4bd58c3367d19e5ffe297be9b58634a3a45b6e24a6d6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-q6_p29ch/wheels/c2/72/ba/c453a8dd999dd8e56a08e111145dde5af8a2b8bbd6c1794af1
# Successfully built ERAlchemy
# Installing collected packages: ERAlchemy
# Successfully installed ERAlchemy-1.2.9

# %% [markdown]
# # **JSON**

# %%
# De una URL
URL = 'http://raw.githubusercontent.com/BindiChen/machine-learning/master/data-analysis/027-pandas-convert-json/data/simple.json'
df = pd.read_json(URL)
df.head(10)
# Out:
#      id   name  math  physics  chemistry
# 0  A001    Tom    60       66         61
# 1  A002  James    89       76         51
# 2  A003  Jenny    79       90         78

# %%
json = pd.read_json('/content/nested_json.json')
json
# Out:
#           school_name   class  \
# 0  ABC primary school  Year 1
# 1  ABC primary school  Year 1
# 2  ABC primary school  Year 1
#
#                                             students
# 0  {'id': 'A001', 'name': 'Tom', 'math': 60, 'phy...
# 1  {'id': 'A002', 'name': 'James', 'math': 89, 'p...
# 2  {'id': 'A003', 'name': 'Jenny', 'math': 79, 'p...

# %%
# Combinando
df_nested_list = pd.json_normalize(
    data,
    record_path =['students'],
    meta=['school_name', 'class']
)
df_nested_list
# Out:
#      id   name  math  physics  chemistry         school_name   class
# 0  A001    Tom    60       66         61  ABC primary school  Year 1
# 1  A002  James    89       76         51  ABC primary school  Year 1
# 2  A003  Jenny    79       90         78  ABC primary school  Year 1

# %%
import json
# Normalizar los datos
with open('nested_json.json','r') as f:
    data = json.loads(f.read())# Flatten data
df_nested_list = pd.json_normalize(data, record_path =['students'])
df_nested_list
# Out:
#      id   name  math  physics  chemistry
# 0  A001    Tom    60       66         61
# 1  A002  James    89       76         51
# 2  A003  Jenny    79       90         78

# %%
# A NORMALIZAR
URL = 'http://api.open-notify.org/astros.json'
df = pd.read_json(URL)
df.head(10)
# Out:
#    message                                          people  number
# 0  success     {'name': 'Jasmin Moghbeli', 'craft': 'ISS'}       7
# 1  success    {'name': 'Andreas Mogensen', 'craft': 'ISS'}       7
# 2  success    {'name': 'Satoshi Furukawa', 'craft': 'ISS'}       7
# 3  success  {'name': 'Konstantin Borisov', 'craft': 'ISS'}       7
# 4  success      {'name': 'Oleg Kononenko', 'craft': 'ISS'}       7
# 5  success        {'name': 'Nikolai Chub', 'craft': 'ISS'}       7
# 6  success        {'name': 'Loral O'Hara', 'craft': 'ISS'}       7

# %% [markdown]
# #**PROXIMAMENTE.......**

# %% [markdown]
# ## APIs

# %%
# !pip install pytrends

# %%
pip install --upgrade --user git+https://github.com/GeneralMills/pytrends

# %%
import pandas as pd
from pytrends.request import TrendReq
pytrends = TrendReq()
keywords = ["barcelona", "Copperfield", "Madrid"]
pytrends.build_payload(keywords, cat=0, geo='', gprop='') # Datos de los ultimos 5 años
stop_queries = pytrends.interest_over_time()[keywords]
stop_queries.head()

# %%
stop_queries.shape

# %%
pytrends.build_payload?

# %% [markdown]
# ## yfinance --> Yahoo Finance

# %%
# !pip install yfinance

# %%
import yfinance as yf
pfe = yf.Ticker('PFE')
pfe.info

# %%
# Scar los dividendos
pfe.actions

# %%
pfe.history

# %%
# period: Valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
# Tambien se puede colocar start, end
hist = pfe.history(period="6mo")
hist

# %% [markdown]
# ## Lectura en serie de datos

# %%
tickers = ['TSLA', 'API', 'LMND','MRK','GOOG']
import matplotlib.pyplot as plt
for i,ticker in enumerate(tickers):
  current_ticker = yf.Ticker(ticker)
  plt.subplot(len(tickers),1,i+1)
  current_ticker.history(period='365d')['Close'].plot(figsize=   (16,60), title='Precio historico de 1 de un año para: '+ticker)

# %%
# Informacion del primero
ticker = tickers[0]
yf_info = yf.Ticker(ticker).info
print(ticker)

# %%
# Creciemito de 52 semanas
yf_info['52WeekChange']

# %%
# Sacando algunas estadisticas de interes
stock_52w_change = []
profitsMargins = []
tickers = ['NVS','JNJ','ABBV','AMGN']
for ticker in tickers:
  print(ticker)
  current_ticker = yf.Ticker(ticker)
  current_ticker_info = current_ticker.info
  stock_52w_change.append(current_ticker_info['52WeekChange'])
  profitsMargins.append(current_ticker_info['profitMargins'])

# %%
stock_52w_change

# %%
profitsMargins

# %%
import pandas as pd
df = pd.DataFrame([stock_52w_change, profitsMargins], columns=tickers, index={'52w change', 'profitMargins'})
print(df)

# %%
import matplotlib.ticker as mtick
ax = df.plot.bar()
ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
ax.set_title('Comparando margenes de profit y tasas de crecimiento en 52 semanas para stocks farmacias')

# %% [markdown]
# ## Marca mas robada

# %%
df2['automotor_marca_descripcion'].value_counts().plot(kind='bar', figsize=(12,6), ylabel='Frecuencia', title='Marcas mas robadas')

# %%
df2['automotor_modelo_descripcion'].value_counts().iloc[0:50].plot(kind='bar', figsize=(12,6), ylabel='Frecuencia', title='Modelos mas robadas')

# %%
df2['titular_genero'].value_counts().plot(kind='bar', figsize=(12,6), ylabel='Frecuencia', title='Robos por genero')

# %%
df2['titular_pais_nacimiento'].value_counts().plot(kind='bar', figsize=(12,6), ylabel='Frecuencia', title='Procedencia del titular')

# %%
df2['titular_domicilio_provincia'].value_counts().plot(kind='bar', figsize=(12,6), ylabel='Frecuencia', title='Procedencia del titular')

# %% [markdown]
# ## Metodo drive

# %%
from google.colab import drive
import os
import pandas as pd
drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive/'
df2 = pd.read_csv('dnrpa-robos-recuperos-autos-202201.csv',sep=",")
df2.head(10)

# %%
df2.shape
print('El df tiene {} instancias y {} features'.format(df2.shape[0],df2.shape[1]))

# %%
df2.dtypes

# %%
df2.describe()

# %%
df2['tramite_fecha']=pd.to_datetime(df2['tramite_fecha']) # Formato datetime python
monthly_accidents =df2.groupby(df2['tramite_fecha'].dt.to_period('D')).size()
monthly_accidents.plot.line(figsize=(12,6))

# %% [markdown]
# ## Metodo local

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
import io
df2 = pd.read_csv(io.BytesIO(uploaded['dnrpa-robos-recuperos-autos-202201.csv']),sep=",")
df2.head(10)

# %%
type(uploaded)
